# %% [markdown]
# # AIS Summer Comp (Advay Vyas)

# %% [markdown]
# ### Imports and data

# %%
# imports
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
import pandas as pd
import numpy as np
from math import sqrt
from xgboost import XGBRegressor

# %%
# load data
train_file_path = '../input/ais-summer-comp-2022/train.csv'
all_data = pd.read_csv(train_file_path)

# %%
# get target
y = all_data['Median House Price']
y.head()
# Out:
# 0    455800
# 1    365700
# 2    298300
# 3    334200
# 4    219100
# Name: Median House Price, dtype: int64

# %%
# creating X
features = ['Population', 'Median Age', 'Unemployment Rate', 'Median Income', 'Poverty Rate']
X = all_data[features]
X.head()
# Out:
#    Population  Median Age  Unemployment Rate  Median Income  Poverty Rate
# 0      840562        35.6                5.1            7.8          26.5
# 1      913161        37.5                4.0            6.2          54.5
# 2      768917        33.0                6.6           15.2          24.5
# 3      710626        42.1                3.1            4.6          53.2
# 4      791257        38.3                3.5            8.1          47.9

# %% [markdown]
# ### XGBoost

# %% [markdown]
# #### Initalize data splits and model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state = 42)
xgb = XGBRegressor(booster = 'gbtree', random_state = 0, max_delta_step = 0)

# %% [markdown]
# #### List of parameters

# %%
from pprint import pprint

print('Parameters in use:\n')
pprint(xgb.get_params())
# Out:
# Parameters in use:
#
# {'base_score': None,
#  'booster': 'gbtree',
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': 0,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'objective': 'reg:squarederror',
#  'predictor': None,
#  'random_state': 0,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %% [markdown]
# #### Hyperparameter grid values

# %%
from sklearn.model_selection import RandomizedSearchCV

subsample = [float(x) for x in np.linspace(start = 0.4, stop = 1, num = 3)]
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 450, num = 5)]
min_child_weight = [int(x) for x in np.linspace(start = 0, stop = 2, num = 3)]
max_depth = [int(x) for x in np.linspace(start = 1, stop = 7, num = 5)]
learning_rate = [float(x) for x in np.linspace(start = 0.1, stop = 0.7, num = 4)]
gamma = [int(x) for x in np.linspace(start = 0, stop = 5, num = 5)]
colsample_bytree = [float(x) for x in np.linspace(start = 0.1, stop = 1, num = 5)]
colsample_bylevel = [float(x) for x in np.linspace(start = 0.1, stop = 1, num = 5)]
colsample_bynode = [float(x) for x in np.linspace(start = 0.1, stop = 1, num = 5)]

# %% [markdown]
# #### Creating random grid to use in tuning with k-fold cross validation

# %%
random_grid = {
    'colsample_bytree': colsample_bytree,
    'colsample_bylevel': colsample_bylevel,
    'colsample_bynode': colsample_bynode,
    'n_estimators': n_estimators,
    'subsample': subsample,
    'max_depth': max_depth,
    'learning_rate': learning_rate,
    'gamma': gamma,
    'min_child_weight': min_child_weight}
               
pprint(random_grid)
# Out:
# {'colsample_bylevel': [0.1, 0.325, 0.55, 0.775, 1.0],
#  'colsample_bynode': [0.1, 0.325, 0.55, 0.775, 1.0],
#  'colsample_bytree': [0.1, 0.325, 0.55, 0.775, 1.0],
#  'gamma': [0, 1, 2, 3, 5],
#  'learning_rate': [0.1, 0.3, 0.5, 0.7],
#  'max_depth': [1, 2, 4, 5, 7],
#  'min_child_weight': [0, 1, 2],
#  'n_estimators': [100, 187, 275, 362, 450],
#  'subsample': [0.4, 0.7, 1.0]}

# %%
xgb_random = RandomizedSearchCV(estimator = xgb, param_distributions = random_grid, n_iter = 150, cv = 5, verbose = 2, 
    random_state = 0, n_jobs = -1) 
xgb_random.fit(X_train, y_train, verbose=False)
xgb_random.best_params_
# Out:
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.325, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.325, gamma=1, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.325, gamma=1, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=1.0, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.7, max_depth=5, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=1, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=1, min_child_weight=2, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=1, min_child_weight=2, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=1, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=7, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.325, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.325, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.775, gamma=5, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.1, gamma=3, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.775, gamma=1, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=0.325, gamma=5, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=100, subsample=0.4; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=0.325, gamma=5, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=100, subsample=0.4; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.775, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=450, subsample=0.7; total time=   1.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=450, subsample=0.7; total time=   1.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.325, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.325, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.325, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=2, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=0, n_estimators=450, subsample=0.7; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.9s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.775, colsample_bytree=0.1, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=187, subsample=0.4; total time=   0.7s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.55, colsample_bytree=1.0, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=1, n_estimators=275, subsample=1.0; total time=   1.0s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.4s[CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.325, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.325, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.7; total time=   0.7s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.325, gamma=1, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=1.0, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   1.0s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.7, max_depth=5, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.7, max_depth=5, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=1, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=1, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=1, min_child_weight=2, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=1, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=7, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=7, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.325, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.775, gamma=5, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.1, gamma=3, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.1, gamma=3, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.775, gamma=1, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=0.325, gamma=5, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=100, subsample=0.4; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=0.325, gamma=5, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=100, subsample=0.4; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.775, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=450, subsample=0.7; total time=   1.5s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.775, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=0, n_estimators=362, subsample=0.4; total time=   1.1s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.775, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=0, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=2, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=0, n_estimators=450, subsample=0.7; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   2.1s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.775, colsample_bytree=0.1, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.775, colsample_bytree=0.1, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=187, subsample=0.4; total time=   0.7s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.55, colsample_bytree=1.0, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.55, colsample_bytree=1.0, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=1, n_estimators=275, subsample=1.0; total time=   1.0s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.4s[CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.325, gamma=1, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=1.0, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.7, max_depth=5, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=1, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=1, min_child_weight=2, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=1, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=1, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.325, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.775, gamma=5, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.775, gamma=5, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.1, gamma=3, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.775, gamma=1, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=0.325, gamma=5, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=100, subsample=0.4; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.775, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.775, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=450, subsample=0.7; total time=   1.5s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.775, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=0, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.325, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.325, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=2, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=2, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=0, n_estimators=450, subsample=0.7; total time=   1.9s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.7s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.775, colsample_bytree=0.1, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=187, subsample=0.4; total time=   0.7s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.55, colsample_bytree=1.0, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=1, n_estimators=275, subsample=1.0; total time=   1.0s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=1, n_estimators=275, subsample=1.0; total time=   1.0s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.55, gamma=0, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   0.9s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.55, gamma=0, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=1, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=100, subsample=1.0; total time=   0.4s[CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.325, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.325, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.325, gamma=1, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=1.0, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=1.0, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=0.55, gamma=2, learning_rate=0.7, max_depth=5, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.775, colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=1, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.55, gamma=5, learning_rate=0.5, max_depth=1, min_child_weight=2, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=1, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=7, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=7, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.325, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.775, gamma=5, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.7; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.1, gamma=3, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.775, gamma=1, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.775, gamma=1, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.775, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=450, subsample=0.7; total time=   1.5s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.775, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=0, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.775, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=0, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=2, min_child_weight=2, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=0, n_estimators=450, subsample=0.7; total time=   1.5s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=5, min_child_weight=0, n_estimators=450, subsample=0.7; total time=   1.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=0, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.775, colsample_bytree=0.1, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.775, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=450, subsample=0.4; total time=   1.6s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=450, subsample=0.4; total time=   1.6s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.55, colsample_bytree=1.0, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.325, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=1, n_estimators=275, subsample=1.0; total time=   1.0s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.55, gamma=0, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=1, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=1, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.325, gamma=0, learning_rate=0.7, max_depth=4, min_child_weight=1, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.55, gamma=0, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   0.9s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=1, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=1, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.325, gamma=0, learning_rate=0.7, max_depth=4, min_child_weight=1, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.325, gamma=0, learning_rate=0.7, max_depth=4, min_child_weight=1, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.775, gamma=2, learning_rate=0.7, max_depth=4, min_child_weight=0, n_estimators=450, subsample=0.7; total time=   1.5s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.775, gamma=3, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.775, gamma=3, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.1, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.1, gamma=0, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.1, gamma=0, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=1.0, gamma=1, learning_rate=0.5, max_depth=2, min_child_weight=0, n_estimators=362, subsample=0.4; total time=   1.1s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=275, subsample=0.7; total time=   0.9s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=0.775, gamma=3, learning_rate=0.5, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.55, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.55, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=1.0, gamma=0, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=275, subsample=0.7; total time=   0.9s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=3, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=3, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.55, gamma=2, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=0, learning_rate=0.1, max_depth=1, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   2.0s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=1.0, gamma=1, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.55, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END colsample_bylevel=0.325, colsample_bynode=1.0, colsample_bytree=0.325, gamma=5, learning_rate=0.3, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.1, gamma=3, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=362, subsample=0.7; total time=   1.3s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=1.0, gamma=0, learning_rate=0.5, max_depth=4, min_child_weight=1, n_estimators=275, subsample=0.7; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=0.55, gamma=0, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=1.0, gamma=0, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   0.9s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=1.0, gamma=0, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   0.9s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.775, gamma=5, learning_rate=0.7, max_depth=2, min_child_weight=0, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.55, gamma=2, learning_rate=0.3, max_depth=5, min_child_weight=2, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.55, colsample_bytree=0.325, gamma=3, learning_rate=0.3, max_depth=2, min_child_weight=0, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=0.1, colsample_bynode=1.0, colsample_bytree=0.55, gamma=2, learning_rate=0.5, max_depth=1, min_child_weight=0, n_estimators=362, subsample=1.0; total time=   1.1s
# [CV] END colsample_bylevel=0.1, colsample_bynode=1.0, colsample_bytree=0.55, gamma=2, learning_rate=0.5, max_depth=1, min_child_weight=0, n_estimators=362, subsample=1.0; total time=   1.1s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=0.1, gamma=5, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=0, learning_rate=0.7, max_depth=7, min_child_weight=2, n_estimators=362, subsample=1.0; total time=   1.3s
# [CV] END colsample_bylevel=0.1, colsample_bynode=1.0, colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.325, gamma=0, learning_rate=0.7, max_depth=4, min_child_weight=1, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.1, gamma=5, learning_rate=0.5, max_depth=1, min_child_weight=0, n_estimators=275, subsample=0.7; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.1, gamma=5, learning_rate=0.5, max_depth=1, min_child_weight=0, n_estimators=275, subsample=0.7; total time=   0.9s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.775, gamma=2, learning_rate=0.7, max_depth=4, min_child_weight=0, n_estimators=450, subsample=0.7; total time=   1.5s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.775, gamma=3, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=187, subsample=0.4; total time=   0.7s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.1, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.1, gamma=0, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.1, gamma=0, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=1.0, gamma=1, learning_rate=0.5, max_depth=2, min_child_weight=0, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=275, subsample=0.7; total time=   0.9s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=7, min_child_weight=2, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.1, colsample_bytree=0.775, gamma=3, learning_rate=0.5, max_depth=7, min_child_weight=2, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.55, gamma=5, learning_rate=0.1, max_depth=2, min_child_weight=1, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=1.0, gamma=0, learning_rate=0.5, max_depth=5, min_child_weight=1, n_estimators=275, subsample=0.7; total time=   0.9s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=3, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=362, subsample=1.0; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.55, gamma=2, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=1.0, colsample_bynode=1.0, colsample_bytree=0.55, gamma=2, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=362, subsample=0.7; total time=   1.2s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=0, learning_rate=0.1, max_depth=1, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.6s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=1.0, gamma=1, learning_rate=0.3, max_depth=1, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.55, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.55, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.325, colsample_bynode=1.0, colsample_bytree=0.325, gamma=5, learning_rate=0.3, max_depth=4, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   0.3s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.1, gamma=3, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=362, subsample=0.4; total time=   1.2s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=7, min_child_weight=0, n_estimators=362, subsample=0.7; total time=   1.3s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.55, colsample_bytree=0.55, gamma=2, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=100, subsample=1.0; total time=   0.3s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.55, colsample_bytree=0.55, gamma=2, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=100, subsample=1.0; total time=   0.3s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.55, colsample_bytree=0.55, gamma=2, learning_rate=0.1, max_depth=1, min_child_weight=2, n_estimators=100, subsample=1.0; total time=   0.3s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=1.0, gamma=0, learning_rate=0.5, max_depth=4, min_child_weight=1, n_estimators=275, subsample=0.7; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=0.55, gamma=0, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=0.55, gamma=0, learning_rate=0.3, max_depth=4, min_child_weight=2, n_estimators=450, subsample=1.0; total time=   1.5s
# ...
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=0.1, gamma=5, learning_rate=0.3, max_depth=2, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.775, colsample_bytree=0.1, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=2, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=1.0, gamma=5, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.55, gamma=0, learning_rate=0.7, max_depth=4, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.325, colsample_bytree=0.55, gamma=0, learning_rate=0.7, max_depth=4, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.6s
# [CV] END colsample_bylevel=1.0, colsample_bynode=0.775, colsample_bytree=0.775, gamma=1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=362, subsample=0.7; total time=   1.3s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=1.0, gamma=0, learning_rate=0.7, max_depth=2, min_child_weight=0, n_estimators=100, subsample=1.0; total time=   0.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.1, colsample_bytree=0.55, gamma=3, learning_rate=0.7, max_depth=4, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=0, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.1, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=0, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.1, gamma=1, learning_rate=0.5, max_depth=2, min_child_weight=1, n_estimators=100, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.775, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=0, n_estimators=450, subsample=0.7; total time=   1.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=1.0, colsample_bytree=0.775, gamma=3, learning_rate=0.1, max_depth=1, min_child_weight=0, n_estimators=450, subsample=0.7; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.775, gamma=2, learning_rate=0.7, max_depth=4, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.1, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=0, n_estimators=275, subsample=0.7; total time=   0.9s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.325, colsample_bytree=0.55, gamma=1, learning_rate=0.3, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=0.1, gamma=2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.775, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.775, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.6s
# {'subsample': 0.4,
#  'n_estimators': 100,
#  'min_child_weight': 0,
#  'max_depth': 1,
#  'learning_rate': 0.1,
#  'gamma': 1,
#  'colsample_bytree': 0.55,
#  'colsample_bynode': 1.0,
#  'colsample_bylevel': 0.55}
# [CV] END colsample_bylevel=0.775, colsample_bynode=1.0, colsample_bytree=0.775, gamma=5, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=0.55, gamma=5, learning_rate=0.7, max_depth=5, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.7s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.325, gamma=1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.325, gamma=1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.55, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=362, subsample=1.0; total time=   1.3s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=2, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.325, gamma=2, learning_rate=0.5, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.7s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.325, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.325, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=0, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.1, gamma=0, learning_rate=0.5, max_depth=4, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.55, gamma=3, learning_rate=0.3, max_depth=2, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.5s
#
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.55, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=362, subsample=1.0; total time=   1.3s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=362, subsample=1.0; total time=   1.3s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=2, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=2, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.325, gamma=2, learning_rate=0.5, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.7s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.325, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=0, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=0, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.4s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.1, gamma=0, learning_rate=0.5, max_depth=4, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.55, gamma=3, learning_rate=0.3, max_depth=2, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.4s
#
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.325, gamma=1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.325, gamma=1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.55, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=362, subsample=1.0; total time=   1.3s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=2, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.325, gamma=2, learning_rate=0.5, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.325, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=0, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.1, gamma=0, learning_rate=0.5, max_depth=4, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.1, gamma=0, learning_rate=0.5, max_depth=4, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.55, gamma=3, learning_rate=0.3, max_depth=2, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.0s
#
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.1, colsample_bytree=0.55, gamma=5, learning_rate=0.7, max_depth=5, min_child_weight=1, n_estimators=187, subsample=0.7; total time=   0.7s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.55, gamma=3, learning_rate=0.1, max_depth=5, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.55, colsample_bytree=0.325, gamma=1, learning_rate=0.5, max_depth=7, min_child_weight=1, n_estimators=275, subsample=0.4; total time=   1.0s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.55, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.55, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.1, colsample_bytree=0.1, gamma=3, learning_rate=0.3, max_depth=7, min_child_weight=0, n_estimators=362, subsample=1.0; total time=   1.3s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.55, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=2, min_child_weight=2, n_estimators=187, subsample=1.0; total time=   0.6s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.775, gamma=1, learning_rate=0.7, max_depth=1, min_child_weight=2, n_estimators=275, subsample=1.0; total time=   0.9s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.325, colsample_bytree=1.0, gamma=3, learning_rate=0.1, max_depth=4, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.325, gamma=2, learning_rate=0.5, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.1, colsample_bynode=0.775, colsample_bytree=0.325, gamma=2, learning_rate=0.5, max_depth=1, min_child_weight=0, n_estimators=187, subsample=0.4; total time=   0.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.55, colsample_bytree=0.325, gamma=3, learning_rate=0.7, max_depth=7, min_child_weight=0, n_estimators=187, subsample=1.0; total time=   0.7s
# [CV] END colsample_bylevel=0.775, colsample_bynode=0.775, colsample_bytree=0.325, gamma=0, learning_rate=0.7, max_depth=1, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END colsample_bylevel=0.55, colsample_bynode=0.325, colsample_bytree=0.1, gamma=0, learning_rate=0.5, max_depth=4, min_child_weight=2, n_estimators=450, subsample=0.4; total time=   1.6s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.55, gamma=3, learning_rate=0.3, max_depth=2, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.5s
# [CV] END colsample_bylevel=0.325, colsample_bynode=0.325, colsample_bytree=0.55, gamma=3, learning_rate=0.3, max_depth=2, min_child_weight=0, n_estimators=450, subsample=1.0; total time=   1.0s

# %% [markdown]
# #### Evaluating the results of k-fold cross-validation

# %%
def evaluate(model, X_test, y_test):
    predictions = model.predict(X_test)
    error = sqrt(mean_squared_error(y_test, predictions))
    print('RMSE')
    print(error)

# %%
baseline_model = XGBRegressor(random_state = 42, booster='gbtree', reg_alpha = 10, 
 subsample = 0.667, n_estimators = 427, min_child_weight = 0, max_depth = 3, 
    max_delta_step = 0, learning_rate = 0.105, gamma = 4, sampling_method = 'gradient_based', 
tree_method = 'gpu_hist')
baseline_model.fit(X_train, y_train, early_stopping_rounds=5, eval_set=[(X_test, y_test)], verbose=False)
base_accuracy = evaluate(baseline_model, X_test, y_test)
# Out:
# RMSE
# 126511.43075965442
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:797: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   UserWarning,

# %%
refined_model = XGBRegressor(random_state = 0, booster='gbtree', 
subsample = 0.4, n_estimators = 100, min_child_weight = 0, max_depth = 1,
max_delta_step = 0, learning_rate = 0.1, gamma = 1, colsample_bytree = 0.55, 
colsample_bynode = 1.0, colsample_bylevel = 0.55, sampling_method = 'gradient_based', 
tree_method = 'gpu_hist')
refined_model.fit(X_train, y_train, early_stopping_rounds=5, eval_set=[(X_test, y_test)], verbose=False)
refined_accuracy = evaluate(refined_model, X_test, y_test)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:797: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   UserWarning,
# RMSE
# 177551.43963218894

# %% [markdown]
# ### Predicting competition data

# %%
# reading competition data
competition_data_path = '../input/ais-summer-comp-2022/evaluation_input.csv'
competition_data = pd.read_csv(competition_data_path)
competition_data.head()
# Out:
#      ID  Population  Median Age  Unemployment Rate  Median Income  \
# 0  TX35      857654        33.0                4.1           18.4
# 1  PR16      678333        43.0                4.6           13.5
# 2   NY4      730314        40.4                3.6            5.7
# 3   OR1      858875        38.0                3.8            8.9
# 4   GA8      706237        37.6                5.3           17.3
#
#    Poverty Rate
# 0          25.2
# 1          28.3
# 2          43.6
# 3          40.7
# 4          22.7

# %%
# creating competition X
competition_X = competition_data[features]
competition_X.head()
# Out:
#    Population  Median Age  Unemployment Rate  Median Income  Poverty Rate
# 0      857654        33.0                4.1           18.4          25.2
# 1      678333        43.0                4.6           13.5          28.3
# 2      730314        40.4                3.6            5.7          43.6
# 3      858875        38.0                3.8            8.9          40.7
# 4      706237        37.6                5.3           17.3          22.7

# %%
# competition predictions
competition_preds = baseline_model.predict(competition_X)
print(competition_preds)
# Out:
# [ 304751.8    120980.84   405587.28   321851.44   158552.61   231876.9
#   284866.97   317118.25   431714.1     95182.74   415547.03   321851.44
#   429956.44   374514.28   169515.86   196658.53   349846.28   329454.3
#   196647.19   246710.38   364559.78   152910.4    224420.47   411784.
#   538398.44   727809.     536325.9    380898.53   506050.06   172938.02
#   318956.12   531291.7    216958.92   186621.98   217216.94   310970.6
#   167761.88   373627.03   339528.3    246860.84   213961.7     90994.62
#   220285.3    439628.97   374079.75   461585.25   362868.25   335326.38
#   283948.78    76253.695  223130.58  1032382.44   336494.84   173474.33
#   278129.22   190100.9    308258.03   175997.61   341537.72   274918.47
#   422854.3    289173.25   406307.16   190755.66   150784.33   447834.06
#   242755.12   437601.     390831.16   366123.06   272105.3    186438.28
#   382499.34   173569.05   233962.55   346504.9    332026.4    184527.67
#   166859.44   186613.8    165350.14   159871.06   230864.14   309169.78
#   547720.25   243940.83   201775.2    335943.75   181424.94   290826.97
#   100484.086  325313.2    277638.88   487964.4    207350.36   196873.19
#   359396.53   158767.23   353812.1    271486.62   285902.75   567378.75
#   111544.87   159871.06   355621.56   239467.2    425438.1     79652.11
#   146825.88   217152.44   348864.88   276440.47   218025.6    197634.06
#   135923.4    182245.62   174575.52   435762.25   411944.44   259988.27
#   306797.97   616025.25   219379.84   360099.25   239653.97   381688.1
#   429956.44   251440.14   883369.1    424128.75   209268.5    378771.16
#   192254.05   535128.94   268869.1    193682.58   275172.7    451949.38
#   129805.39   371681.72  1149454.6    209786.66   533768.1    235497.42
#   332396.03   377011.1    162969.58   333363.7    528236.7    183697.84
#   238578.86   262724.97   282407.72   406795.06   196647.19   260055.36
#   424756.1    354535.22   159786.7    366099.9    317649.1    388969.9
#   478544.88   352951.94   223571.73   195666.22   172192.03   172866.61
#   358897.34   195154.17   430888.7    241357.31   336494.84   453520.1
#   194198.58   166168.72   371522.5    398378.9    343643.75   396301.97
#   289999.72   215950.19   192444.84   351847.1    180493.4    338982.97
#   240405.66   234895.88   180488.1    454536.8    271815.03   363366.53
#   149554.58   262049.9    440240.97  1021618.7    159786.7    144329.11
#   382425.84   321851.44   329597.25   489509.47   366443.8    393799.38
#   489509.47   272712.5    304506.72   182933.7    128867.8    167068.61
#   493284.4    306945.72 ]

# %% [markdown]
# ### Generating submission

# %%
# Creating and outputting DataFrame
output = pd.DataFrame({'ID': competition_data.ID, 'Median House Price': competition_preds})
output.to_csv('Vyas_Advay_answer.csv', index=False)
